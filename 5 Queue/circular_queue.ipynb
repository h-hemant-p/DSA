# %%
class CircularQueue:
    def __init__(self, capacity):
        self.capacity = capacity
        self.queue = [None] * capacity
        self.front = -1  # Index of the front element
        self.rear = -1   # Index of the last element
        self.size = 0    # Current number of elements

    def is_empty(self):
        return self.size == 0

    def is_full(self):
        return self.size == self.capacity

    def enqueue(self, item):
        if self.is_full():
            raise OverflowError("Queue is full")
        
        if self.is_empty():
            self.front = 0
        
        self.rear = (self.rear + 1) % self.capacity
        self.queue[self.rear] = item
        self.size += 1
        return True

    def dequeue(self):
        if self.is_empty():
            raise IndexError("Queue is empty")
        
        item = self.queue[self.front]
        self.queue[self.front] = None
        if self.front == self.rear:
            self.front = -1
            self.rear = -1
        else:
            self.front = (self.front + 1) % self.capacity
        self.size -= 1
        return item

    def peek(self):
        if self.is_empty():
            raise IndexError("Queue is empty")
        return self.queue[self.front]

    def get_size(self):
        return self.size

# Example usage
if __name__ == "__main__":
    cq = CircularQueue(5)
    
    # Enqueue elements
    cq.enqueue(1)
    cq.enqueue(2)
    cq.enqueue(3)
    print(f"Queue size: {cq.get_size()}")  # Output: Queue size: 3
    print(f"Front element: {cq.peek()}")   # Output: Front element: 1
    
    # Dequeue elements
    print(f"Dequeued: {cq.dequeue()}")     # Output: Dequeued: 1
    print(f"Queue size: {cq.get_size()}")  # Output: Queue size: 2
    
    # Enqueue more elements
    cq.enqueue(4)
    cq.enqueue(5)
    cq.enqueue(6)  # Queue is now full
    
    # Try to enqueue when full
    try:
        cq.enqueue(7)
    except OverflowError as e:
        print(f"Error: {e}")  # Output: Error: Queue is full
    
    # Dequeue all elements
    while not cq.is_empty():
        print(f"Dequeued: {cq.dequeue()}")
# Out:
# Queue size: 3
# Front element: 1
# Dequeued: 1
# Queue size: 2
# Error: Queue is full
# Dequeued: 2
# Dequeued: 3
# Dequeued: 4
# Dequeued: 5
# Dequeued: 6
